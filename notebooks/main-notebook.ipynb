# %%
import Annotation
import Video

# %%
Video.VideoCompressor('./examples/videos', './examples/npy_videos')
Annotation.AnnotationsCompressor('./examples/alignments', './examples/npy_alignments')
# Out:
# ...
# 100%|██████████| 2/2 [00:00<00:00, 1319.79it/s]

# %%
from utils import plot_metric, float_array_form_file

# %%
losses = float_array_form_file('metrics/losses.txt')
plot_metric(losses, label='loss')

# %%
accs = float_array_form_file('metrics/accs.txt')
plot_metric(accs, label='accuracy')
